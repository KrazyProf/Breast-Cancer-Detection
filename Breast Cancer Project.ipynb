# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import confusion_matrix,accuracy_score

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv('Data.csv')
x = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %% [markdown]
# ## Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x = sc.fit_transform(x)

# %% [markdown]
# ## Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size = 0.25 , random_state = 0)

# %% [markdown]
# # Logistic Regression

# %% [markdown]
# ## Training the Logistic Regression model on the Training set

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 0)
classifier.fit(x_train , y_train)
# Out:
# LogisticRegression(random_state=0)

# %% [markdown]
# ## Predicting a new result

# %%
y_pred =classifier.predict(x_test)
np.concatenate((y_pred.reshape(len(y_pred) , 1) , y_test.reshape(len(y_test) , 1)),1)
# Out:
# array([[2, 2],
#        [2, 2],
#        [4, 4],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [4, 4],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [4, 4],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [4, 4],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [4, 4],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [4, 2],
# ...

# %% [markdown]
# ## Making the Confusion Matrix

# %%
confusion_matrix(y_test , y_pred)
# Out:
# array([[103,   4],
#        [  5,  59]])

# %%
accuracy_score(y_test , y_pred)
# Out:
# 0.9473684210526315

# %% [markdown]
# # Support Vector Machine

# %% [markdown]
# ## Training the Support Vector Machine model on the Training set

# %%
from sklearn.svm import SVC
svm_l = SVC(kernel= 'linear' , random_state = 0)
svm_l.fit(x_train , y_train)
# Out:
# SVC(kernel='linear', random_state=0)

# %% [markdown]
# ## Prediction a new Result

# %%
svm_pred = svm_l.predict(x_test)
np.concatenate((svm_pred.reshape(len(svm_pred) ,1 ) , y_test.reshape(len(y_test) ,1 )) , 1)
# Out:
# array([[2, 2],
#        [2, 2],
#        [4, 4],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [4, 2],
#        [4, 4],
#        [4, 4],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [4, 4],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [4, 4],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [4, 4],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [4, 2],
# ...

# %% [markdown]
# ## Making the Confusion Matrix

# %%
confusion_matrix(y_test, svm_pred)
# Out:
# array([[102,   5],
#        [  5,  59]])

# %%
accuracy_score(y_test, svm_pred)
# Out:
# 0.9415204678362573

# %% [markdown]
# # Kernel SVM

# %% [markdown]
# ## Training the Support Vector Machine model on the Training set

# %%
from sklearn.svm import SVC
svm_r = SVC(kernel= 'rbf' , random_state = 0)
svm_r.fit(x_train , y_train)
# Out:
# SVC(random_state=0)

# %% [markdown]
# ## Prediction a new Result

# %%
svm_pred_r = svm_r.predict(x_test)
np.concatenate((svm_pred_r.reshape(len(svm_pred_r) ,1 ) , y_test.reshape(len(y_test) ,1 )) , 1)
# Out:
# array([[2, 2],
#        [2, 2],
#        [4, 4],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [4, 2],
#        [4, 4],
#        [4, 4],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [4, 4],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [4, 4],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [4, 4],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [4, 2],
# ...

# %% [markdown]
# ## Making the Confusion Matrix

# %%
confusion_matrix(y_test, svm_pred_r)
# Out:
# array([[102,   5],
#        [  3,  61]])

# %%
accuracy_score(y_test, svm_pred_r)
# Out:
# 0.9532163742690059

# %% [markdown]
# # KNN

# %% [markdown]
# ## Training the KNN model on the Training set

# %%
from sklearn.neighbors import KNeighborsClassifier
k_neighbor = KNeighborsClassifier(n_neighbors= 10 , metric= 'minkowski')
k_neighbor.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %% [markdown]
# ## Prediction a new Result

# %%
y_pred_n = k_neighbor.predict(x_test)
np.concatenate((y_pred_n.reshape(len(y_pred_n) ,1 ) , y_test.reshape(len(y_test) ,1 )) , 1)
# Out:
# array([[2, 2],
#        [2, 2],
#        [4, 4],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [4, 4],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [4, 4],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [4, 4],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [4, 4],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [4, 2],
# ...

# %% [markdown]
# ## Making the Confusion Matrix

# %%
confusion_matrix(y_test, y_pred_n)
# Out:
# array([[103,   4],
#        [  6,  58]])

# %%
accuracy_score(y_test, y_pred_n)
# Out:
# 0.9415204678362573

# %% [markdown]
# # Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
nb.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred_nb = nb.predict(x_test)
np.concatenate((y_pred_nb.reshape(len(y_pred_nb) ,1 ) , y_test.reshape(len(y_test) ,1 )) , 1)
# Out:
# array([[2, 2],
#        [2, 2],
#        [4, 4],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [4, 2],
#        [4, 4],
#        [4, 4],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [4, 4],
#        [4, 4],
#        [2, 2],
#        [4, 2],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [4, 4],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [4, 4],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [4, 2],
# ...

# %%
confusion_matrix(y_test, y_pred_nb)
# Out:
# array([[99,  8],
#        [ 2, 62]])

# %%
accuracy_score(y_test, y_pred_nb)
# Out:
# 0.9415204678362573

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
tree_c = DecisionTreeClassifier(criterion= 'entropy' , random_state = 0)
tree_c.fit(x_train ,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
y_pred_tree = tree_c.predict(x_test)
np.concatenate((y_pred_tree.reshape(len(y_pred_tree) ,1 ) , y_test.reshape(len(y_test) ,1 )) , 1)
# Out:
# array([[2, 2],
#        [2, 2],
#        [4, 4],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [4, 4],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [4, 4],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [4, 4],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [4, 4],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [4, 2],
# ...

# %%
confusion_matrix(y_test, y_pred_tree)
# Out:
# array([[103,   4],
#        [  3,  61]])

# %%
accuracy_score(y_test, y_pred_tree)
# Out:
# 0.9590643274853801

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rand_forest = RandomForestClassifier(n_estimators= 500 , random_state = 0 , criterion= 'gini')
rand_forest.fit(x_train , y_train)
# Out:
# RandomForestClassifier(n_estimators=500, random_state=0)

# %%
y_pred_rand_forest= rand_forest.predict(x_test)
np.concatenate((y_pred_rand_forest.reshape(len(y_pred_rand_forest) ,1 ) , y_test.reshape(len(y_test) ,1 )) , 1)
# Out:
# array([[2, 2],
#        [2, 2],
#        [4, 4],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [4, 4],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [4, 4],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [4, 4],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [4, 4],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [4, 4],
#        [2, 2],
#        [2, 2],
#        [2, 2],
#        [4, 4],
#        [4, 2],
# ...

# %%
confusion_matrix(y_test, y_pred_rand_forest)
# Out:
# array([[103,   4],
#        [  4,  60]])

# %%
accuracy_score(y_test, y_pred_rand_forest)
# Out:
# 0.9532163742690059
